# %%
# %matplotlib inline
import os.path as osp
import matplotlib.pyplot as plt
import numpy as np
import scipy.io as sio

import mpet.mod_cell as mod_cell
import mpet.geometry as geom
import mpet.props_am as props_am
import mpet.utils as utils
from mpet.config import Config, constants

import os

# %%
def plot_interface(resultDir, vol, part, var, tval):
    matfile = osp.join(resultDir, 'output_data.mat')
    sim_output = sio.loadmat(matfile)
    times = sim_output['phi_applied_times'][0]
    config = Config.from_dicts(resultDir)

    Nvol = config["Nvol"]
    trodes = config["trodes"]
    Npart = config["Npart"]
    psd_len = config["psd_len"]

    # Pick out some useful calculated values
    k = constants.k                      # Boltzmann constant, J/(K Li)
    Tref = constants.T_ref               # Temp, K
    e = constants.e                      # Charge of proton, C
    F = constants.F                      # C/mol
    c_ref = constants.c_ref
    td = config["t_ref"]
    Etheta = {"a": 0.}
    for trode in trodes:
        Etheta[trode] = -(k*Tref/e) * config[trode, "phiRef"]
    Vstd = Etheta["c"] - Etheta["a"]
    
    trode = 'c'
    t = np.argmin(np.abs(times - tval))
    if tval > times[-1]:
        raise ValueError(f'Max time: {times[-1]}, got {tval}')
    
    var_names = {'c': 'concentration',
                 'phi': 'potential'}
    var_long = var_names[var]
    
    fig, axes = plt.subplots(ncols=2, sharey=True, figsize=(8, 4))
    
    key = f'interfaceTrode{trode}vol{vol}part{part}_{var}'
    nvol_i = sim_output[key].shape[1]
    
    Lfac = 1e6
    Lunit = r"$\mu$m"
    dxc = config["L"]["c"]/Nvol["c"]
    dxvec = np.array(Nvol["c"] * [dxc])
    porosvec = np.array(Nvol["c"] * [config["poros"]["c"]])
    cellsvec = dxc*np.arange(Nvol["c"]) + dxc/2.
    cellsvec_c = dxc*np.arange(Nvol["c"]) + dxc/2.
    cellsvec_c *=config["L_ref"] * Lfac
    
    dxs = config["L_i"]/nvol_i
    dxvec_i = np.array(nvol_i * [dxs])
    dxvec = np.hstack((dxvec_i, dxvec))
    poros_i = np.array(nvol_i * [config["poros_i"]])
    cellsvec += config["L_i"] / config["L"]["c"]
    cellsvec_i = dxs*np.arange(nvol_i) + dxs/2.
    cellsvec_i *= config["L_ref"] * Lfac

    # elyte data
    key = f'{var}_lyte_{trode}'
    if var in 'c':
        data_elyte = sim_output[key][:, vol]* c_ref / 1000.  # select correct elyte volume
    elif var in 'phi':
        data_elyte = sim_output[key][:, vol]*(k*Tref/e) - Vstd  # select correct elyte volume
    # elyte value at timestep chosen to plot interface region volumes
    cval = data_elyte[t]
    data_elyte_vol = sim_output[key][t]  # all volumes at given t
    
    # interface data
    key = f'interfaceTrode{trode}vol{vol}part{part}_{var}'
    # select all time steps, middle volume
    ind = int(nvol_i / 2)
    if var in 'c':
        data_iface = sim_output[key][:, vol]* c_ref / 1000.  # select correct elyte volume
        data_iface_vol = sim_output[key][t]* c_ref / 1000.
    elif var in 'phi':
        data_iface = sim_output[key][:, vol]*(k*Tref/e) - Vstd  # select correct elyte volume
        data_iface_vol = sim_output[key][t]*(k*Tref/e) - Vstd  # all volumes at given t
    
    # time vs variable
    ax = axes[0]
    ax.plot(times, data_elyte, label='elyte')
    ax.plot(times, data_iface, label='iface central volume',c='m')

    ax.set_xlabel('time')
    ax.set_ylabel(var_long)
    ax.axvline(tval, ls='--', c='k')
    ax.axhline(cval, ls='--', c='k')
    ax.legend()
    ax.set_title('Time evolution')

    #  volume vs variable
    ax = axes[1]   
#     ax.plot(data_iface_vol, marker='o', label='iface volumes')
    ax.plot(cellsvec_i,data_iface_vol, marker='o', label='iface volumes',c='m')
    ax.scatter(-cellsvec_i[0], cval, label='elyte output')
    print(var_long, "elyte", cval)
    print(var_long, "iface", data_iface_vol)
    ax.set_xlabel('Interface position [um]')
    ax.legend()
    ax.set_title('Interface volumes')
#     ax.set_ylim(-2, 2)

    fig.suptitle(var_long)
    fig.tight_layout()
    
    return sim_output

# %%
# to run mpet from jupyter
#!mpetrun.py mpet-dev/configs/params_system_solid.cfg # >/dev/null; echo $?

# %%
resultDir = 'sim_output'
# resultDir = 'history\\100_100_c'
vol = 0  # volume to plot
part = 0  # particle to plot
tval = 100  # which timestep to show (in seconds)

for var in ['c', 'phi']:
    sim_output = plot_interface(resultDir, vol, part, var, tval)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-736ce8c1131d> in <module>()
#       6
#       7 for var in ['c', 'phi']:
# ----> 8     sim_output = plot_interface(resultDir, vol, part, var, tval)
#
# <ipython-input-17-a352c9d1598f> in plot_interface(resultDir, vol, part, var, tval)
#      34
#      35     key = f'interfaceTrode{trode}vol{vol}part{part}_{var}'
# ---> 36     nvol_i = sim_output[key].shape[1]
#      37
#      38     Lfac = 1e6
#
# KeyError: 'interfaceTrodecvol0part0_c'

# %%
def plot_battery(resultDir, vol, part, var, tval):
    matfile = osp.join(resultDir, 'output_data.mat')
    sim_output = sio.loadmat(matfile)
    times = sim_output['phi_applied_times'][0]
    config = Config.from_dicts(resultDir)

    Nvol = config["Nvol"]
    trodes = config["trodes"]
    Npart = config["Npart"]
    psd_len = config["psd_len"]
    dD_e = {}
    ndD_e = {}

    # Pick out some useful calculated values
    k = constants.k                      # Boltzmann constant, J/(K Li)
    Tref = constants.T_ref               # Temp, K
    e = constants.e                      # Charge of proton, C
    F = constants.F                      # C/mol
    c_ref = constants.c_ref
    td = config["t_ref"]
    Etheta = {"a": 0.}
    for trode in trodes:
        Etheta[trode] = -(k*Tref/e) * config[trode, "phiRef"]
    Vstd = Etheta["c"] - Etheta["a"]
    
    Lfac = 1e6
    Lunit = r"$\mu$m"
    dxc = config["L"]["c"]/Nvol["c"]
    dxvec = np.array(Nvol["c"] * [dxc])
    porosvec = np.array(Nvol["c"] * [config["poros"]["c"]])
    cellsvec = dxc*np.arange(Nvol["c"]) + dxc/2.
    cellsvec_c = dxc*np.arange(Nvol["c"]) + dxc/2.
    cellsvec_c *= config["L_ref"] * Lfac
    if Nvol["s"]:
        dxs = config["L"]["s"]/Nvol["s"]
        dxvec_s = np.array(Nvol["s"] * [dxs])
        dxvec = np.hstack((dxvec_s, dxvec))
        poros_s = np.array(Nvol["s"] * [config["poros"]["s"]])
        porosvec = np.hstack((poros_s, porosvec))
        cellsvec += config["L"]["s"] / config["L"]["c"]
        cellsvec_s = dxs*np.arange(Nvol["s"]) + dxs/2.
        cellsvec = np.hstack((cellsvec_s, cellsvec))
    if "a" in trodes:
        dxa = config["L"]["a"]/Nvol["a"]
        dxvec_a = np.array(Nvol["a"] * [dxa])
        dxvec = np.hstack((dxvec_a, dxvec))
        poros_a = np.array(Nvol["a"] * [config["poros"]["a"]])
        porosvec = np.hstack((poros_a, porosvec))
        cellsvec += config["L"]["a"] / config["L"]["c"]
        cellsvec_a = dxa*np.arange(Nvol["a"]) + dxa/2.
        cellsvec = np.hstack((cellsvec_a, cellsvec))
    cellsvec_s *= config["L_ref"] * Lfac
    cellsvec *= config["L_ref"] * Lfac
    facesvec = np.insert(np.cumsum(dxvec), 0, 0.) * config["L_ref"] * Lfac
    
    # Uncomment these lines to show the variables you can plot
    # for k in sim_output.keys():
    #     print(k)
    # return

    trode = 'c'
    t = np.argmin(np.abs(times - tval))
    if tval > times[-1]:
        raise ValueError(f'Max time: {times[-1]}, got {tval}')
    
    var_names = {'c': 'concentration',
                 'phi': 'potential'}
    var_long = var_names[var]
    
    fig, axes = plt.subplots(ncols=2, sharey=True, figsize=(8, 4))

    # elyte data elyte
    key = f'{var}_lyte_s'
    if var in 'c':
        data_elyte_s = sim_output[key]* c_ref / 1000.  # select correct elyte volume
    elif var in 'phi':
        data_elyte_s = sim_output[key]*(k*Tref/e) - Vstd
    x_elyte_s = list(range(-np.shape(data_elyte_s)[1],0))
    # elyte value at timestep chosen to plot interface region volumes
    if var in 'c':
        cval_s = data_elyte_s[t]
    elif var in 'phi':
        cval_s = data_elyte_s[t]
    data_elyte_vol_s = sim_output[key][t]  # all volumes at given t
    
    # elyte data electrode
    key = f'{var}_lyte_{trode}'
    if var in 'c':
        data_elyte_c = sim_output[key]* c_ref / 1000.  # select correct elyte volume
    elif var in 'phi':
        data_elyte_c = sim_output[key]*(k*Tref/e) - Vstd
    x_elyte_c = list(range(np.shape(data_elyte_c)[1]))
    # elyte value at timestep chosen to plot interface region volumes
    if var in 'c':
        cval_c = data_elyte_c[t]
    elif var in 'phi':
        cval_c = data_elyte_c[t]
    data_elyte_vol_c = sim_output[key][t]  # all volumes at given t
    
    # time vs variable
    ax = axes[0]
    ax.plot(times, data_elyte_c)
    ax.plot(times, data_elyte_s[:,-1], label='elyte_s last volume')

    ax.set_xlabel('time')
    ax.set_ylabel(var_long)
    ax.axvline(tval, ls='--', c='k')
#    ax.axhline(cval_c, ls='--', c='k')
    ax.legend()
    ax.set_title('Time evolution')

    #  volume vs variable
    ax = axes[1]   
#     ax.plot(x_elyte_c,cval_c, marker='o', label='elyte_c')
#     ax.plot(x_elyte_s,cval_s , label='elyte_s', c='g', marker='o')
    
#     datay = np.hstack((cval_s, cval_c))
#     ax.plot(cellsvec,datay , label='elyte_s', c='g', marker='o')
    
    ax.plot(cellsvec_s[-1]+cellsvec_c,cval_c, marker='o', label='elyte_c')
    ax.plot(cellsvec_s,cval_s , label='elyte_s', c='g', marker='o')
    
    ax.set_xlabel('Battery position [um]')
    ax.legend()
#    ax.set_ylim(0, 0.7)

    fig.suptitle(var_long)
    fig.tight_layout()
    
    return sim_output

# %%
resultDir = 'sim_output'
vol = 0  # volume to plot
part = 3  # particle to plot
tval = 100  # which timestep to show (in seconds)

for var in ['c', 'phi']:
    sim_output = plot_battery(resultDir, vol, part, var, tval)

# %%
def plot_i(resultDir, vol, part, var, tval):
    matfile = osp.join(resultDir, 'output_data.mat')
    sim_output = sio.loadmat(matfile)
    times = sim_output['phi_applied_times'][0]
    numtimes = len(times)
    config = Config.from_dicts(resultDir)

    Nvol = config["Nvol"]
    trodes = config["trodes"]
    Npart = config["Npart"]
    psd_len = config["psd_len"]
    
    # Pick out some useful calculated values
    k = constants.k                      # Boltzmann constant, J/(K Li)
    Tref = constants.T_ref               # Temp, K
    e = constants.e                      # Charge of proton, C
    F = constants.F                      # C/mol
    c_ref = constants.c_ref
    
#     # Uncomment these lines to show the variables you can plot
#     for k in sim_output.keys():
#         print(k)
#     return

    trode = 'c'
    t = np.argmin(np.abs(times - tval))
    if tval > times[-1]:
        raise ValueError(f'Max time: {times[-1]}, got {tval}')
    
    var_names = {'c': 'concentration',
                 'phi': 'potential'}
    var_long = var_names[var]
    
    key = f'interfaceTrode{trode}vol{vol}part{part}_{var}'
    nvol_i = sim_output[key].shape[1]
    
    Lfac = 1e6
    Lunit = r"$\mu$m"
    dxc = config["L"]["c"]/Nvol["c"]
    dxvec = np.array(Nvol["c"] * [dxc])
    porosvec = np.array(Nvol["c"] * [config["poros"]["c"]])
    cellsvec = dxc*np.arange(Nvol["c"]) + dxc/2.
    cellsvec_c = dxc*np.arange(Nvol["c"]) + dxc/2.
    cellsvec_c *=config["L_ref"] * Lfac
    
    dxs = config["L_i"]/nvol_i
    dxvec_i = np.array(nvol_i * [dxs])
    dxvec = np.hstack((dxvec_i, dxvec))
    poros_i = np.array(nvol_i * [config["poros_i"]])
    cellsvec += config["L_i"] / config["L"]["c"]
    cellsvec_i = dxs*np.arange(nvol_i) + dxs/2.
    cellsvec_i *= config["L_ref"] * Lfac
    facesvec_i = np.insert(np.cumsum(dxvec_i), 0, 0.) * config["L_ref"] * Lfac

    t = np.argmin(np.abs(times - tval))
    if tval > times[-1]:
        raise ValueError(f'Max time: {times[-1]}, got {tval}')

    Nvol = config["Nvol_i"]
    
    key_c = f'interfaceTrodecvol{vol}part{part}_c'
    key_phi = f'interfaceTrodecvol{vol}part{part}_phi'

    cGP_L, pGP_L = sim_output['c_lyteGP_L'], sim_output['phi_lyteGP_L']
    c_int, phi_int = sim_output[key_c], sim_output[key_phi]
    cmat = np.hstack((c_int[:, 0].reshape((numtimes, 1)), c_int, c_int[:, -1].reshape((numtimes, 1))))
    pmat = np.hstack((phi_int[:, 0].reshape((numtimes, 1)), phi_int, phi_int[:, -1].reshape((numtimes, 1))))
    disc = geom.get_interface_disc(Nvol, config["L_i"], config["poros_i"], config["BruggExp_i"])

    i_edges = np.zeros((numtimes, np.shape(cmat)[1]-1))

    for tInd in range(numtimes):
        i_edges[tInd, :] = mod_cell.get_lyte_internal_fluxes(cmat[tInd, :], pmat[tInd, :], disc, config)[1]

    ylbl = r'Current density of interface [A/m$^2$]'
    datax = range(np.shape(cmat)[1]-1)
    datay = i_edges * (F*c_ref*config["D_ref"]/config["L_ref"])
    #datay = i_edges
    
    ax = axes[0]
    ax.plot(times,datay[:,1], marker='o')
    ax.axvline(tval, ls='--', c='k')
    ax.set_xlabel('time [s]')
    ax.set_ylabel(ylbl)
    
    ax = axes[1]
    #ax.plot(datax,datay[t,:], marker='o')
    ax.plot(facesvec_i,datay[t,:], marker='o')
    ax.set_xlabel('Interface position [um]')
    
    #total_current_i = np.zeros(5)
    #total_current_i = datay[t,:]
    #print(total_current_i)
    
    fig.suptitle('Current density')
    fig.tight_layout()
    
    return sim_output

# %%
resultDir = 'sim_output'

fig, axes = plt.subplots(ncols=2, sharey=True, figsize=(8, 4))

tval = 250  # which timestep to show (in seconds)

for vol in [0]:
    for part in [0]:
        sim_output = plot_i(resultDir, vol, part, var, tval)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-0c86d773d923> in <module>()
#       7 for vol in [0]:
#       8     for part in [0]:
# ----> 9         sim_output = plot_i(resultDir, vol, part, var, tval)
#
# <ipython-input-7-1591cd3b97c6> in plot_i(resultDir, vol, part, var, tval)
#      33
#      34     key = f'interfaceTrode{trode}vol{vol}part{part}_{var}'
# ---> 35     nvol_i = sim_output[key].shape[1]
#      36
#      37     Lfac = 1e6
#
# KeyError: 'interfaceTrodecvol0part0_phi'

# %%
    # Uncomment these lines to show the variables you can plot
    for k in sim_output.keys():
        print(k)
    return
# Out:
# __header__
# __version__
# __globals__
# R_Vp_c
# R_Vp_c_times
# c_lyteGP_L
# c_lyteGP_L_times
# c_lyte_c
# c_lyte_c_times
# c_lyte_s
# c_lyte_s_times
# current
# current_times
# ffrac_c
# ffrac_c_times
# partTrodecvol0part0_Rxn
# partTrodecvol0part0_Rxn_times
# partTrodecvol0part0_c
# partTrodecvol0part0_c_times
# partTrodecvol0part0_cbar
# partTrodecvol0part0_cbar_times
# partTrodecvol0part0_dcbardt
# partTrodecvol0part0_dcbardt_times
# partTrodecvol0part1_Rxn
# partTrodecvol0part1_Rxn_times
# partTrodecvol0part1_c
# partTrodecvol0part1_c_times
# partTrodecvol0part1_cbar
# partTrodecvol0part1_cbar_times
# partTrodecvol0part1_dcbardt
# partTrodecvol0part1_dcbardt_times
# partTrodecvol0part1_portInBulk_phi_m
# partTrodecvol0part1_portInBulk_phi_m_times
# partTrodecvol0part1_portInLyte_c_lyte
# partTrodecvol0part1_portInLyte_c_lyte_times
# partTrodecvol0part1_portInLyte_phi_lyte
# partTrodecvol0part1_portInLyte_phi_lyte_times
# partTrodecvol0part2_Rxn
# partTrodecvol0part2_Rxn_times
# partTrodecvol0part2_c
# partTrodecvol0part2_c_times
# partTrodecvol0part2_cbar
# partTrodecvol0part2_cbar_times
# partTrodecvol0part2_dcbardt
# partTrodecvol0part2_dcbardt_times
# partTrodecvol0part2_portInBulk_phi_m
# partTrodecvol0part2_portInBulk_phi_m_times
# partTrodecvol0part2_portInLyte_c_lyte
# partTrodecvol0part2_portInLyte_c_lyte_times
# partTrodecvol0part2_portInLyte_phi_lyte
# partTrodecvol0part2_portInLyte_phi_lyte_times
# partTrodecvol0part3_Rxn
# partTrodecvol0part3_Rxn_times
# partTrodecvol0part3_c
# partTrodecvol0part3_c_times
# partTrodecvol0part3_cbar
# partTrodecvol0part3_cbar_times
# partTrodecvol0part3_dcbardt
# partTrodecvol0part3_dcbardt_times
# partTrodecvol0part3_portInBulk_phi_m
# partTrodecvol0part3_portInBulk_phi_m_times
# partTrodecvol0part3_portInLyte_c_lyte
# partTrodecvol0part3_portInLyte_c_lyte_times
# partTrodecvol0part3_portInLyte_phi_lyte
# partTrodecvol0part3_portInLyte_phi_lyte_times
# partTrodecvol0part4_Rxn
# partTrodecvol0part4_Rxn_times
# partTrodecvol0part4_c
# partTrodecvol0part4_c_times
# partTrodecvol0part4_cbar
# partTrodecvol0part4_cbar_times
# partTrodecvol0part4_dcbardt
# partTrodecvol0part4_dcbardt_times
# partTrodecvol0part4_portInBulk_phi_m
# partTrodecvol0part4_portInBulk_phi_m_times
# partTrodecvol0part4_portInLyte_c_lyte
# partTrodecvol0part4_portInLyte_c_lyte_times
# partTrodecvol0part4_portInLyte_phi_lyte
# partTrodecvol0part4_portInLyte_phi_lyte_times
# partTrodecvol1part0_Rxn
# partTrodecvol1part0_Rxn_times
# partTrodecvol1part0_c
# partTrodecvol1part0_c_times
# partTrodecvol1part0_cbar
# partTrodecvol1part0_cbar_times
# partTrodecvol1part0_dcbardt
# partTrodecvol1part0_dcbardt_times
# partTrodecvol1part1_Rxn
# partTrodecvol1part1_Rxn_times
# partTrodecvol1part1_c
# partTrodecvol1part1_c_times
# partTrodecvol1part1_cbar
# partTrodecvol1part1_cbar_times
# partTrodecvol1part1_dcbardt
# partTrodecvol1part1_dcbardt_times
# partTrodecvol1part1_portInBulk_phi_m
# partTrodecvol1part1_portInBulk_phi_m_times
# partTrodecvol1part1_portInLyte_c_lyte
# partTrodecvol1part1_portInLyte_c_lyte_times
# partTrodecvol1part1_portInLyte_phi_lyte
# partTrodecvol1part1_portInLyte_phi_lyte_times
# partTrodecvol1part2_Rxn
# partTrodecvol1part2_Rxn_times
# partTrodecvol1part2_c
# partTrodecvol1part2_c_times
# partTrodecvol1part2_cbar
# partTrodecvol1part2_cbar_times
# partTrodecvol1part2_dcbardt
# partTrodecvol1part2_dcbardt_times
# partTrodecvol1part2_portInBulk_phi_m
# partTrodecvol1part2_portInBulk_phi_m_times
# partTrodecvol1part2_portInLyte_c_lyte
# partTrodecvol1part2_portInLyte_c_lyte_times
# partTrodecvol1part2_portInLyte_phi_lyte
# partTrodecvol1part2_portInLyte_phi_lyte_times
# partTrodecvol1part3_Rxn
# partTrodecvol1part3_Rxn_times
# partTrodecvol1part3_c
# partTrodecvol1part3_c_times
# partTrodecvol1part3_cbar
# partTrodecvol1part3_cbar_times
# partTrodecvol1part3_dcbardt
# partTrodecvol1part3_dcbardt_times
# partTrodecvol1part3_portInBulk_phi_m
# partTrodecvol1part3_portInBulk_phi_m_times
# partTrodecvol1part3_portInLyte_c_lyte
# partTrodecvol1part3_portInLyte_c_lyte_times
# partTrodecvol1part3_portInLyte_phi_lyte
# partTrodecvol1part3_portInLyte_phi_lyte_times
# partTrodecvol1part4_Rxn
# partTrodecvol1part4_Rxn_times
# partTrodecvol1part4_c
# partTrodecvol1part4_c_times
# partTrodecvol1part4_cbar
# partTrodecvol1part4_cbar_times
# partTrodecvol1part4_dcbardt
# partTrodecvol1part4_dcbardt_times
# partTrodecvol1part4_portInBulk_phi_m
# partTrodecvol1part4_portInBulk_phi_m_times
# partTrodecvol1part4_portInLyte_c_lyte
# partTrodecvol1part4_portInLyte_c_lyte_times
# partTrodecvol1part4_portInLyte_phi_lyte
# partTrodecvol1part4_portInLyte_phi_lyte_times
# partTrodecvol2part0_Rxn
# partTrodecvol2part0_Rxn_times
# partTrodecvol2part0_c
# partTrodecvol2part0_c_times
# partTrodecvol2part0_cbar
# partTrodecvol2part0_cbar_times
# partTrodecvol2part0_dcbardt
# partTrodecvol2part0_dcbardt_times
# partTrodecvol2part1_Rxn
# partTrodecvol2part1_Rxn_times
# partTrodecvol2part1_c
# partTrodecvol2part1_c_times
# partTrodecvol2part1_cbar
# partTrodecvol2part1_cbar_times
# partTrodecvol2part1_dcbardt
# partTrodecvol2part1_dcbardt_times
# partTrodecvol2part1_portInBulk_phi_m
# partTrodecvol2part1_portInBulk_phi_m_times
# partTrodecvol2part1_portInLyte_c_lyte
# partTrodecvol2part1_portInLyte_c_lyte_times
# partTrodecvol2part1_portInLyte_phi_lyte
# partTrodecvol2part1_portInLyte_phi_lyte_times
# partTrodecvol2part2_Rxn
# partTrodecvol2part2_Rxn_times
# partTrodecvol2part2_c
# partTrodecvol2part2_c_times
# partTrodecvol2part2_cbar
# partTrodecvol2part2_cbar_times
# partTrodecvol2part2_dcbardt
# partTrodecvol2part2_dcbardt_times
# partTrodecvol2part2_portInBulk_phi_m
# partTrodecvol2part2_portInBulk_phi_m_times
# partTrodecvol2part2_portInLyte_c_lyte
# partTrodecvol2part2_portInLyte_c_lyte_times
# partTrodecvol2part2_portInLyte_phi_lyte
# partTrodecvol2part2_portInLyte_phi_lyte_times
# partTrodecvol2part3_Rxn
# partTrodecvol2part3_Rxn_times
# partTrodecvol2part3_c
# partTrodecvol2part3_c_times
# partTrodecvol2part3_cbar
# partTrodecvol2part3_cbar_times
# partTrodecvol2part3_dcbardt
# partTrodecvol2part3_dcbardt_times
# partTrodecvol2part3_portInBulk_phi_m
# partTrodecvol2part3_portInBulk_phi_m_times
# partTrodecvol2part3_portInLyte_c_lyte
# partTrodecvol2part3_portInLyte_c_lyte_times
# partTrodecvol2part3_portInLyte_phi_lyte
# partTrodecvol2part3_portInLyte_phi_lyte_times
# partTrodecvol2part4_Rxn
# partTrodecvol2part4_Rxn_times
# partTrodecvol2part4_c
# partTrodecvol2part4_c_times
# partTrodecvol2part4_cbar
# partTrodecvol2part4_cbar_times
# partTrodecvol2part4_dcbardt
# partTrodecvol2part4_dcbardt_times
# partTrodecvol2part4_portInBulk_phi_m
# partTrodecvol2part4_portInBulk_phi_m_times
# partTrodecvol2part4_portInLyte_c_lyte
# partTrodecvol2part4_portInLyte_c_lyte_times
# partTrodecvol2part4_portInLyte_phi_lyte
# partTrodecvol2part4_portInLyte_phi_lyte_times
# partTrodecvol3part0_Rxn
# partTrodecvol3part0_Rxn_times
# partTrodecvol3part0_c
# partTrodecvol3part0_c_times
# partTrodecvol3part0_cbar
# partTrodecvol3part0_cbar_times
# partTrodecvol3part0_dcbardt
# partTrodecvol3part0_dcbardt_times
# partTrodecvol3part1_Rxn
# partTrodecvol3part1_Rxn_times
# partTrodecvol3part1_c
# partTrodecvol3part1_c_times
# partTrodecvol3part1_cbar
# partTrodecvol3part1_cbar_times
# partTrodecvol3part1_dcbardt
# partTrodecvol3part1_dcbardt_times
# partTrodecvol3part1_portInBulk_phi_m
# partTrodecvol3part1_portInBulk_phi_m_times
# partTrodecvol3part1_portInLyte_c_lyte
# partTrodecvol3part1_portInLyte_c_lyte_times
# partTrodecvol3part1_portInLyte_phi_lyte
# partTrodecvol3part1_portInLyte_phi_lyte_times
# partTrodecvol3part2_Rxn
# partTrodecvol3part2_Rxn_times
# partTrodecvol3part2_c
# partTrodecvol3part2_c_times
# partTrodecvol3part2_cbar
# partTrodecvol3part2_cbar_times
# partTrodecvol3part2_dcbardt
# partTrodecvol3part2_dcbardt_times
# partTrodecvol3part2_portInBulk_phi_m
# partTrodecvol3part2_portInBulk_phi_m_times
# partTrodecvol3part2_portInLyte_c_lyte
# partTrodecvol3part2_portInLyte_c_lyte_times
# partTrodecvol3part2_portInLyte_phi_lyte
# partTrodecvol3part2_portInLyte_phi_lyte_times
# partTrodecvol3part3_Rxn
# partTrodecvol3part3_Rxn_times
# partTrodecvol3part3_c
# partTrodecvol3part3_c_times
# partTrodecvol3part3_cbar
# partTrodecvol3part3_cbar_times
# partTrodecvol3part3_dcbardt
# partTrodecvol3part3_dcbardt_times
# partTrodecvol3part3_portInBulk_phi_m
# partTrodecvol3part3_portInBulk_phi_m_times
# partTrodecvol3part3_portInLyte_c_lyte
# partTrodecvol3part3_portInLyte_c_lyte_times
# partTrodecvol3part3_portInLyte_phi_lyte
# partTrodecvol3part3_portInLyte_phi_lyte_times
# partTrodecvol3part4_Rxn
# partTrodecvol3part4_Rxn_times
# partTrodecvol3part4_c
# partTrodecvol3part4_c_times
# partTrodecvol3part4_cbar
# partTrodecvol3part4_cbar_times
# partTrodecvol3part4_dcbardt
# partTrodecvol3part4_dcbardt_times
# partTrodecvol3part4_portInBulk_phi_m
# partTrodecvol3part4_portInBulk_phi_m_times
# partTrodecvol3part4_portInLyte_c_lyte
# partTrodecvol3part4_portInLyte_c_lyte_times
# partTrodecvol3part4_portInLyte_phi_lyte
# partTrodecvol3part4_portInLyte_phi_lyte_times
# partTrodecvol4part0_Rxn
# partTrodecvol4part0_Rxn_times
# partTrodecvol4part0_c
# partTrodecvol4part0_c_times
# partTrodecvol4part0_cbar
# partTrodecvol4part0_cbar_times
# partTrodecvol4part0_dcbardt
# partTrodecvol4part0_dcbardt_times
# partTrodecvol4part1_Rxn
# partTrodecvol4part1_Rxn_times
# partTrodecvol4part1_c
# partTrodecvol4part1_c_times
# partTrodecvol4part1_cbar
# partTrodecvol4part1_cbar_times
# partTrodecvol4part1_dcbardt
# partTrodecvol4part1_dcbardt_times
# partTrodecvol4part1_portInBulk_phi_m
# partTrodecvol4part1_portInBulk_phi_m_times
# partTrodecvol4part1_portInLyte_c_lyte
# partTrodecvol4part1_portInLyte_c_lyte_times
# partTrodecvol4part1_portInLyte_phi_lyte
# partTrodecvol4part1_portInLyte_phi_lyte_times
# partTrodecvol4part2_Rxn
# partTrodecvol4part2_Rxn_times
# partTrodecvol4part2_c
# partTrodecvol4part2_c_times
# partTrodecvol4part2_cbar
# partTrodecvol4part2_cbar_times
# partTrodecvol4part2_dcbardt
# partTrodecvol4part2_dcbardt_times
# partTrodecvol4part2_portInBulk_phi_m
# partTrodecvol4part2_portInBulk_phi_m_times
# partTrodecvol4part2_portInLyte_c_lyte
# partTrodecvol4part2_portInLyte_c_lyte_times
# partTrodecvol4part2_portInLyte_phi_lyte
# partTrodecvol4part2_portInLyte_phi_lyte_times
# partTrodecvol4part3_Rxn
# partTrodecvol4part3_Rxn_times
# partTrodecvol4part3_c
# partTrodecvol4part3_c_times
# partTrodecvol4part3_cbar
# partTrodecvol4part3_cbar_times
# partTrodecvol4part3_dcbardt
# partTrodecvol4part3_dcbardt_times
# partTrodecvol4part3_portInBulk_phi_m
# partTrodecvol4part3_portInBulk_phi_m_times
# partTrodecvol4part3_portInLyte_c_lyte
# partTrodecvol4part3_portInLyte_c_lyte_times
# partTrodecvol4part3_portInLyte_phi_lyte
# partTrodecvol4part3_portInLyte_phi_lyte_times
# partTrodecvol4part4_Rxn
# partTrodecvol4part4_Rxn_times
# partTrodecvol4part4_c
# partTrodecvol4part4_c_times
# partTrodecvol4part4_cbar
# partTrodecvol4part4_cbar_times
# partTrodecvol4part4_dcbardt
# partTrodecvol4part4_dcbardt_times
# partTrodecvol4part4_portInBulk_phi_m
# partTrodecvol4part4_portInBulk_phi_m_times
# partTrodecvol4part4_portInLyte_c_lyte
# partTrodecvol4part4_portInLyte_c_lyte_times
# partTrodecvol4part4_portInLyte_phi_lyte
# partTrodecvol4part4_portInLyte_phi_lyte_times
# phi_applied
# phi_applied_times
# phi_bulk_c
# phi_bulk_c_times
# phi_cell
# phi_cell_times
# phi_lyteGP_L
# phi_lyteGP_L_times
# phi_lyte_c
# phi_lyte_c_times
# phi_lyte_s
# phi_lyte_s_times
# phi_part_c
# phi_part_c_times
#   File "<ipython-input-9-293b51855a46>", line 4
#     return
#           ^
# SyntaxError: 'return' outside function
